# %% [markdown]
# # Octave set-up Notebook
# <img style="float:right;" src="https://id.dewberry.com/clients/Templates/DewberryLogo_RGB.png" width=150px>
#
#
# #### - Steps to follow:
#   1. Download the [Octave executable](https://ftp.gnu.org/gnu/octave/windows/octave-4.4.0-w64_1-installer.exe)
#   2. Import Libraries & Assign Paths
#   3. Assign Tasks
#   4. Save Report

# %% [markdown]
# ### Directions to installing the Octave executable
# 1. Download and run the Octave executable
# 2. Then after go to the control panel -> system and security -> system -> advanced -> environment variables
# 3. Find the path variable and edit it and add the path to the Octave bin directory
# 4. Open anaconda and install oct2py
#
#
#
# * Could also install the octave kernel too

# %%
from oct2py import octave

# %%
octave.addpath(r'C:\Users\tmiesse\Work\Flood_lab_notebooks\data');

# %%
out = octave.test_datatypes();
# Out:
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#     logical =
#
#       0  0  0  1  1
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#     logical =
#
#       0  0  0  1  1
#
#     string =
#
#       scalar structure containing the fields:
#
#         basic = spam
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#     logical =
#
#       0  0  0  1  1
#
#     string =
#
#       scalar structure containing the fields:
#
#         basic = spam
#         char_array =
#         {
#           [1,1] = spam
#           [2,1] = foo
#           [1,2] = eggs
#           [2,2] = bar
#         }
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#     logical =
#
#       0  0  0  1  1
#
#     string =
#
#       scalar structure containing the fields:
#
#         basic = spam
#         char_array =
#         {
#           [1,1] = spam
#           [2,1] = foo
#           [1,2] = eggs
#           [2,2] = bar
#         }
#
#         cell_array =
#         {
#           [1,1] = spam
#           [1,2] = eggs
#         }
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#     logical =
#
#       0  0  0  1  1
#
#     string =
#
#       scalar structure containing the fields:
#
#         basic = spam
#         char_array =
#         {
#           [1,1] = spam
#           [2,1] = foo
#           [1,2] = eggs
#           [2,2] = bar
#         }
#
#         cell_array =
#         {
#           [1,1] = spam
#           [1,2] = eggs
#         }
#
#
#     struct =
#
#       scalar structure containing the fields:
#
#         array =
#
#           scalar structure containing the fields:
#
#             name: 1x6 sq_string
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#     logical =
#
#       0  0  0  1  1
#
#     string =
#
#       scalar structure containing the fields:
#
#         basic = spam
#         char_array =
#         {
#           [1,1] = spam
#           [2,1] = foo
#           [1,2] = eggs
#           [2,2] = bar
#         }
#
#         cell_array =
#         {
#           [1,1] = spam
#           [1,2] = eggs
#         }
#
#
#     struct =
#
#       scalar structure containing the fields:
#
#         array =
#
#           scalar structure containing the fields:
#
#             name: 1x6 sq_string
#             age: 1x1 scalar
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#     logical =
#
#       0  0  0  1  1
#
#     string =
#
#       scalar structure containing the fields:
#
#         basic = spam
#         char_array =
#         {
#           [1,1] = spam
#           [2,1] = foo
#           [1,2] = eggs
#           [2,2] = bar
#         }
#
#         cell_array =
#         {
#           [1,1] = spam
#           [1,2] = eggs
#         }
#
#
#     struct =
#
#       scalar structure containing the fields:
#
#         array =
#
#           1x2 struct array containing the fields:
#
#             name
#             age
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#     logical =
#
#       0  0  0  1  1
#
#     string =
#
#       scalar structure containing the fields:
#
#         basic = spam
#         char_array =
#         {
#           [1,1] = spam
#           [2,1] = foo
#           [1,2] = eggs
#           [2,2] = bar
#         }
#
#         cell_array =
#         {
#           [1,1] = spam
#           [1,2] = eggs
#         }
#
#
#     struct =
#
#       scalar structure containing the fields:
#
#         array =
#
#           1x2 struct array containing the fields:
#
#             name
#             age
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#     logical =
#
#       0  0  0  1  1
#
#     string =
#
#       scalar structure containing the fields:
#
#         basic = spam
#         char_array =
#         {
#           [1,1] = spam
#           [2,1] = foo
#           [1,2] = eggs
#           [2,2] = bar
#         }
#
#         cell_array =
#         {
#           [1,1] = spam
#           [1,2] = eggs
#         }
#
#
#     struct =
#
#       scalar structure containing the fields:
#
#         array =
#
#           1x2 struct array containing the fields:
#
#             name
#             age
#
#
#     cell =
#
#       scalar structure containing the fields:
#
#         vector =
#         {
#           [1,1] = spam
#           [1,2] =  4
#           [1,3] =
#
#              1   2   3
#
#         }
#
#
#
# test =
#
#   scalar structure containing the fields:
#
#     num =
#
#       scalar structure containing the fields:
#
#         int =
#
#           scalar structure containing the fields:
#
#             int8: 1x1 int8 scalar
#             int16: 1x1 int16 scalar
#             int32: 1x1 int32 scalar
#             int64: 1x1 int64 scalar
#             uint8: 1x1 uint8 scalar
#             uint16: 1x1 uint16 scalar
#             uint32: 1x1 uint32 scalar
#             uint64: 1x1 uint64 scalar
#
#         float32 =  3.1416
#         float64 =  3.1416
#         complex =  3 + 1i
#         complex_matrix =
#
#            0.61279 + 0.61279i   0.32001 + 0.32001i
#            0.85086 + 0.85086i   0.72062 + 0.72062i
#
#         inf =  Inf
#         NaN =  NaN
#         matrix =
#
#            1   2
#            3   4
#
#         vector =
#
#            1   2   3   4
#
#         column_vector =
#
#            1
#            2
#            3
#            4
#
#         matrix3d =
#
#         ans(:,:,1) =
#
#            0.67230   0.82970   0.66732
#            0.58644   0.68420   0.59671
#
#         ans(:,:,2) =
#
#            0.84011   0.45689   0.20752
#            0.55527   0.24655   0.53952
#
#         ans(:,:,3) =
#
#            0.782691   0.106620   0.961668
#            0.026501   0.514480   0.840761
#
#         ans(:,:,4) =
#
#            0.26840   0.48099   0.12167
#            0.32173   0.22778   0.80604
#
#         matrix5d =
#
#         ans(:,:,1,1,1) =
#
#            0.23364   0.75158
#
#         ans(:,:,2,1,1) =
#
#            0.37799   0.92881
#
#         ans(:,:,3,1,1) =
#
#            0.715296   0.084174
#
#         ans(:,:,1,2,1) =
#
#            0.22578   0.18986
#
#         ans(:,:,2,2,1) =
#
#            0.93366   0.78117
#
#         ans(:,:,3,2,1) =
#
#            0.86060   0.85582
#
#         ans(:,:,1,3,1) =
#
#            0.12353   0.36184
#
#         ans(:,:,2,3,1) =
#
#            0.72796   0.66105
#
#         ans(:,:,3,3,1) =
#
#            0.53394   0.40069
#
#         ans(:,:,1,4,1) =
#
#            0.302654   0.016255
#
#         ans(:,:,2,4,1) =
#
#            0.75246   0.72309
#
#         ans(:,:,3,4,1) =
#
#            0.41877   0.17335
#
#         ans(:,:,1,1,2) =
#
#            0.80526   0.38524
#
#         ans(:,:,2,1,2) =
#
#            0.015368   0.772826
#
#         ans(:,:,3,1,2) =
#
#            0.65487   0.17153
#
#         ans(:,:,1,2,2) =
#
#            0.36344   0.83295
#
#         ans(:,:,2,2,2) =
#
#            0.72081   0.20097
#
#         ans(:,:,3,2,2) =
#
#            0.76084   0.45783
#
#         ans(:,:,1,3,2) =
#
#            0.46987   0.12228
#
#         ans(:,:,2,3,2) =
#
#            0.78383   0.22718
#
#         ans(:,:,3,3,2) =
#
#            0.83705   0.97747
#
#         ans(:,:,1,4,2) =
#
#            0.56331   0.36251
#
#         ans(:,:,2,4,2) =
#
#            0.45336   0.42673
#
#         ans(:,:,3,4,2) =
#
#            0.900640   0.044786
#
#         ans(:,:,1,1,3) =
#
#            0.89903   0.70007
#
#         ans(:,:,2,1,3) =
#
#            0.84649   0.37444
#
#         ans(:,:,3,1,3) =
#
#            0.071176   0.932190
#
#         ans(:,:,1,2,3) =
#
#            0.62073   0.34337
#
#         ans(:,:,2,2,3) =
#
#            0.43453   0.75331
#
#         ans(:,:,3,2,3) =
#
#            0.18624   0.58702
#
#         ans(:,:,1,3,3) =
#
#            0.906584   0.041800
#
#         ans(:,:,2,3,3) =
#
#            0.64743   0.37034
#
#         ans(:,:,3,3,3) =
#
#            0.47741   0.91823
#
#         ans(:,:,1,4,3) =
#
#            0.902185   0.057132
#
#         ans(:,:,2,4,3) =
#
#            0.46420   0.62702
#
#         ans(:,:,3,4,3) =
#
#            0.29640   0.17320
#
#         ans(:,:,1,1,4) =
#
#            0.75674   0.89613
#
#         ans(:,:,2,1,4) =
#
#            0.607247   0.091873
#
#         ans(:,:,3,1,4) =
#
#            0.98429   0.32497
#
#         ans(:,:,1,2,4) =
#
#            0.80575   0.96518
#
#         ans(:,:,2,2,4) =
#
#            0.99121   0.60385
#
#         ans(:,:,3,2,4) =
#
#            0.82934   0.39128
#
#         ans(:,:,1,3,4) =
#
#            0.17137   0.91248
#
#         ans(:,:,2,3,4) =
#
#            0.32177   0.41690
#
#         ans(:,:,3,3,4) =
#
#            0.75036   0.73217
#
#         ans(:,:,1,4,4) =
#
#            0.73061   0.64209
#
#         ans(:,:,2,4,4) =
#
#            0.020808   0.381134
#
#         ans(:,:,3,4,4) =
#
#            0.65097   0.25094
#
#         ans(:,:,1,1,5) =
#
#            0.44278   0.12894
#
#         ans(:,:,2,1,5) =
#
#            0.861167   0.060474
#
#         ans(:,:,3,1,5) =
#
#            0.96683   0.18891
#
#         ans(:,:,1,2,5) =
#
#            0.22727   0.55170
#
#         ans(:,:,2,2,5) =
#
#            0.51064   0.98320
#
#         ans(:,:,3,2,5) =
#
#            0.32279   0.13642
#
#         ans(:,:,1,3,5) =
#
#            0.79081   0.44224
#
#         ans(:,:,2,3,5) =
#
#            0.50807   0.78442
#
#         ans(:,:,3,3,5) =
#
#            0.51578   0.88421
#
#         ans(:,:,1,4,5) =
#
#            0.31661   0.55466
#
#         ans(:,:,2,4,5) =
#
#            0.763770   0.018503
#
#         ans(:,:,3,4,5) =
#
#            0.49850   0.23533
#
#
#     logical =
#
#       0  0  0  1  1
#
#     string =
#
#       scalar structure containing the fields:
#
#         basic = spam
#         char_array =
#         {
#           [1,1] = spam
#           [2,1] = foo
#           [1,2] = eggs
#           [2,2] = bar
#         }
#
#         cell_array =
#         {
#           [1,1] = spam
#           [1,2] = eggs
#         }
#
#
#     struct =
#
#       scalar structure containing the fields:
#
#         array =
#
#           1x2 struct array containing the fields:
#
#             name
#             age
#
#
#     cell =
#
#       scalar structure containing the fields:
#
#         vector =
#         {
#           [1,1] = spam
#           [1,2] =  4
#           [1,3] =
#
#              1   2   3
#
#         }
#
#         matrix =
#         {
#           [1,1] = Bob
#           [2,1] = Pam
#           [1,2] =  40
#           [2,2] =  41
#         }

# %%
# %octave
import numpy as np
from oct2py import Oct2Py

# %%
oc = Oct2Py()

# %%
print(oc.abs(-1))
# Out:
# 1

# %%
print(oc.upper('xyz'))
# Out:
# XYZ

# %%
# %%octave -s 600,200 -f png
#
# % Note: On Windows, this will not show the plots unless Ghostscript is installed.
#
# subplot(121);
# [x, y] = meshgrid(0:0.1:3);
# r = sin(x - 0.5).^2 + cos(y - 0.5).^2;
# surf(x, y, r);
#
# subplot(122);
# sombrero()

# %%
# %%octave -f svg -h 300
# sombrero()
# #figure()
# imshow(rand(200,200))

# %%
# %%octave -f svg
#
# p = [12 -2.5 -8 -0.1 8];
# x = 0:0.01:1;
#
# polyout(p, 'x')
# plot(x, polyval(p, x));
# Out:
# 12*x^4 - 2.5*x^3 - 8*x^2 - 0.1*x^1 + 8

# %%
# %%octave -g
# plot([1,2,3])
# # brings up an Octave plotting GUI
